# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---

# %% [markdown]
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well known problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.  https://keras.io/

# %% [markdown]
# ##Exercise 2.1: Text Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layers Neural Network to perfrom classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import tensorflow_datasets as tfds
import time

import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)
# os.environ['TF_DETERMINISTIC_OPS']='1'

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Tensorflow Dataset. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes from a larger news corups. The total number of training samples is 120,000 and testing 7,600. Each class contains 30,000 training samples and 1,900 testing samples. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.
#
# We will split the training set into two 90%-10% splits in order to have a validation set.

# %%
### NOTE ### 
# running this cell might yield download-related errors.
# just repeating the execution a couple of times should solve the error.

train_ds, valid_ds, test_ds = tfds.load('ag_news_subset',
                                        as_supervised=True, # return a set of (text, label) tuples 
                                        split=['train[:90%]', 'train[-10%:]', 'test'],
                                        batch_size=-1)  
                                        # ^ using batch_size=-1 returns Tensors instead of Dataset objects
# Out:
# Downloading and preparing dataset ag_news_subset/1.0.0 (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteC9MWQG/ag_news_subset-train.tfrecord
#   0%|          | 0/120000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteC9MWQG/ag_news_subset-test.tfrecord
#   0%|          | 0/7600 [00:00<?, ? examples/s]
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.

# %%
# Tensors have two elements, data and labels; let's split them
# so we can transform the data
X_train, y_train = train_ds
X_valid, y_valid = valid_ds
X_test, y_test = test_ds

# %% [markdown]
# The AG News Subset dataset consists in news articles, each one composed by a sequence of words. In order to encode each article in a single tensor with a fixed number of elements, we will use multi-hot encoding. For testing purposes, we will only consider the first 10,000  most common words. Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
num_words = 1000
vectorize_layer = tf.keras.layers.TextVectorization(
 max_tokens=num_words,
 standardize="lower_and_strip_punctuation",
 split="whitespace",
 output_mode='multi_hot',
 pad_to_max_tokens=True)

vectorize_layer.adapt(X_train)

# %%
X_train = vectorize_layer(X_train)
X_valid = vectorize_layer(X_valid)
X_test  = vectorize_layer(X_test)

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (`keras.models.Sequential`) and add four layers to it by calling its `add()` method:
#
#
# *   a input layer (`tf.keras.Input`) that is the first layer in your model. With this layer you should specify the `input_shape` argument, leaving out the batch size: `(num_words,)`;
# *  a Dense layer (`keras.layers.Dense`) with 16 neurons, and the "relu" activation function;
# * another Dense layer with 16 neurons, also with the "relu" activation function;
# * a final Dense layer with 4 output neurons, and with the "softmax" activation (since we considering a classification task with four classes).

# %%
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# %% [markdown]
# Call the model's `summary()` method to check if the model has been built correctly. Also, try using `keras.utils.plot_model()` to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                16016
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 16,356
# Trainable params: 16,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (`None`), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# Instaed of using `add()` method it is also possibile to define the model using the following syntax

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(4, activation="softmax")
])
model.summary()
keras.utils.plot_model(model, "my_model.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                16016
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 16,356
# Trainable params: 16,356
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its `compile()` method to specify the loss function and the optimizer to use.
#
# Since the model performs a classification task, and we have labels encoded as integers, we use the sparse categorical cross-entropy loss. As optimizer we use Adam.
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify `metrics=["accuracy"]`.

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its `fit()` method, passing to it the input features (`X_train`) and the target classes (`y_train`). Set the number of epochs to 20.
# In order to validate our model we will also pass the validation data by setting `validation_data=(X_valid, y_valid)`. Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the `fit()` method will return a `History` object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.8503 - accuracy: 0.6761 - val_loss: 0.5107 - val_accuracy: 0.8314
# Epoch 2/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4583 - accuracy: 0.8449 - val_loss: 0.4452 - val_accuracy: 0.8475
# Epoch 3/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4222 - accuracy: 0.8546 - val_loss: 0.4318 - val_accuracy: 0.8507
# Epoch 4/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4089 - accuracy: 0.8573 - val_loss: 0.4241 - val_accuracy: 0.8509
# Epoch 5/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4012 - accuracy: 0.8590 - val_loss: 0.4210 - val_accuracy: 0.8525
# Epoch 6/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3959 - accuracy: 0.8601 - val_loss: 0.4175 - val_accuracy: 0.8531
# Epoch 7/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3917 - accuracy: 0.8615 - val_loss: 0.4149 - val_accuracy: 0.8535
# Epoch 8/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3882 - accuracy: 0.8617 - val_loss: 0.4132 - val_accuracy: 0.8550
# Epoch 9/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3851 - accuracy: 0.8627 - val_loss: 0.4109 - val_accuracy: 0.8540
# Epoch 10/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3825 - accuracy: 0.8629 - val_loss: 0.4096 - val_accuracy: 0.8534
# Epoch 11/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3799 - accuracy: 0.8637 - val_loss: 0.4081 - val_accuracy: 0.8539
# Epoch 12/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3775 - accuracy: 0.8638 - val_loss: 0.4064 - val_accuracy: 0.8543
# Epoch 13/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3753 - accuracy: 0.8645 - val_loss: 0.4051 - val_accuracy: 0.8538
# Epoch 14/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3731 - accuracy: 0.8649 - val_loss: 0.4053 - val_accuracy: 0.8543
# Epoch 15/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3709 - accuracy: 0.8660 - val_loss: 0.4035 - val_accuracy: 0.8553
# Epoch 16/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3689 - accuracy: 0.8661 - val_loss: 0.4027 - val_accuracy: 0.8553
# Epoch 17/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3669 - accuracy: 0.8668 - val_loss: 0.4011 - val_accuracy: 0.8565
# Epoch 18/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3649 - accuracy: 0.8672 - val_loss: 0.4003 - val_accuracy: 0.8554
# Epoch 19/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3630 - accuracy: 0.8679 - val_loss: 0.3992 - val_accuracy: 0.8559
# Epoch 20/20
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3612 - accuracy: 0.8684 - val_loss: 0.3993 - val_accuracy: 0.8564

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the `plot_learning_acc_and_loss` function because we will reuse it in the next steps.

# %%
def plot_learning_acc_and_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_acc_and_loss(history)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 238/238 [==============================] - 0s 2ms/step - loss: 0.4093 - accuracy: 0.8521
# [0.40926671028137207, 0.8521052598953247]

# %% [markdown]
# [TO COMPLETE] Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in this cell.
#
# \\
# ANSWER:
#
# It is important to use the Validation set to select the best parameters for a model, to tune the model on the best parameters. In this way it is possible to select te best model on the Validation set and evaluate it on the unseen Test set with which we can have a general score of our model.
#
# The Validation set is usefull to see the impact of the parameters of the model trained on the Training set and, thanks to the Model-Selection Curve, one can prevent Over/Under-fitting of the model.

# %% [markdown]
# ## [TO COMPLETE] Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..
#
# [TO COMPLETE] In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(4, activation="softmax")
])
model.summary()
keras.utils.plot_model(model, "my_model.png", show_shapes=True)
#[TO COMPLETE] modify the previuos model in order to obtain a new model that overfits the training data

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=50,
                    validation_data=(X_valid, y_valid))#[TO COMPLETE] epochs

print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                32032
#
#  dense_7 (Dense)             (None, 16)                528
#
#  dense_8 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 32,628
# Trainable params: 32,628
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4717 - accuracy: 0.8278 - val_loss: 0.4134 - val_accuracy: 0.8512
# Epoch 2/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3919 - accuracy: 0.8563 - val_loss: 0.4025 - val_accuracy: 0.8540
# Epoch 3/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3661 - accuracy: 0.8649 - val_loss: 0.3930 - val_accuracy: 0.8572
# Epoch 4/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3450 - accuracy: 0.8728 - val_loss: 0.3940 - val_accuracy: 0.8571
# Epoch 5/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3264 - accuracy: 0.8800 - val_loss: 0.3924 - val_accuracy: 0.8585
# Epoch 6/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3088 - accuracy: 0.8867 - val_loss: 0.4025 - val_accuracy: 0.8587
# Epoch 7/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2919 - accuracy: 0.8936 - val_loss: 0.4131 - val_accuracy: 0.8541
# Epoch 8/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2783 - accuracy: 0.8980 - val_loss: 0.4114 - val_accuracy: 0.8577
# Epoch 9/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2647 - accuracy: 0.9037 - val_loss: 0.4264 - val_accuracy: 0.8532
# Epoch 10/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2529 - accuracy: 0.9076 - val_loss: 0.4361 - val_accuracy: 0.8535
# Epoch 11/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2424 - accuracy: 0.9114 - val_loss: 0.4455 - val_accuracy: 0.8508
# Epoch 12/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2317 - accuracy: 0.9152 - val_loss: 0.4609 - val_accuracy: 0.8534
# Epoch 13/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2228 - accuracy: 0.9184 - val_loss: 0.4765 - val_accuracy: 0.8494
# Epoch 14/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2135 - accuracy: 0.9224 - val_loss: 0.4957 - val_accuracy: 0.8436
# Epoch 15/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2063 - accuracy: 0.9249 - val_loss: 0.5057 - val_accuracy: 0.8475
# Epoch 16/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1988 - accuracy: 0.9278 - val_loss: 0.5281 - val_accuracy: 0.8479
# Epoch 17/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1919 - accuracy: 0.9302 - val_loss: 0.5535 - val_accuracy: 0.8445
# Epoch 18/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1853 - accuracy: 0.9325 - val_loss: 0.5556 - val_accuracy: 0.8469
# Epoch 19/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1798 - accuracy: 0.9348 - val_loss: 0.5780 - val_accuracy: 0.8473
# Epoch 20/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1730 - accuracy: 0.9375 - val_loss: 0.5935 - val_accuracy: 0.8416
# Epoch 21/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1680 - accuracy: 0.9396 - val_loss: 0.6190 - val_accuracy: 0.8407
# Epoch 22/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1636 - accuracy: 0.9406 - val_loss: 0.6443 - val_accuracy: 0.8385
# Epoch 23/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1585 - accuracy: 0.9424 - val_loss: 0.6502 - val_accuracy: 0.8395
# Epoch 24/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1543 - accuracy: 0.9447 - val_loss: 0.6769 - val_accuracy: 0.8371
# Epoch 25/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1506 - accuracy: 0.9456 - val_loss: 0.6943 - val_accuracy: 0.8341
# Epoch 26/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1463 - accuracy: 0.9472 - val_loss: 0.7111 - val_accuracy: 0.8333
# Epoch 27/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1413 - accuracy: 0.9492 - val_loss: 0.7396 - val_accuracy: 0.8351
# Epoch 28/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1386 - accuracy: 0.9495 - val_loss: 0.7573 - val_accuracy: 0.8317
# Epoch 29/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1349 - accuracy: 0.9512 - val_loss: 0.8002 - val_accuracy: 0.8327
# Epoch 30/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1317 - accuracy: 0.9527 - val_loss: 0.8039 - val_accuracy: 0.8303
# Epoch 31/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1283 - accuracy: 0.9543 - val_loss: 0.8352 - val_accuracy: 0.8310
# Epoch 32/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1261 - accuracy: 0.9554 - val_loss: 0.8455 - val_accuracy: 0.8269
# Epoch 33/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1226 - accuracy: 0.9566 - val_loss: 0.8663 - val_accuracy: 0.8289
# Epoch 34/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1199 - accuracy: 0.9567 - val_loss: 0.8813 - val_accuracy: 0.8292
# Epoch 35/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1175 - accuracy: 0.9581 - val_loss: 0.9076 - val_accuracy: 0.8245
# Epoch 36/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1149 - accuracy: 0.9588 - val_loss: 0.9214 - val_accuracy: 0.8263
# Epoch 37/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1124 - accuracy: 0.9600 - val_loss: 0.9731 - val_accuracy: 0.8223
# Epoch 38/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1097 - accuracy: 0.9611 - val_loss: 0.9751 - val_accuracy: 0.8238
# Epoch 39/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1081 - accuracy: 0.9621 - val_loss: 0.9835 - val_accuracy: 0.8239
# Epoch 40/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1063 - accuracy: 0.9625 - val_loss: 1.0094 - val_accuracy: 0.8250
# Epoch 41/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1035 - accuracy: 0.9631 - val_loss: 1.0454 - val_accuracy: 0.8274
# Epoch 42/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1012 - accuracy: 0.9648 - val_loss: 1.0634 - val_accuracy: 0.8213
# Epoch 43/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.1006 - accuracy: 0.9642 - val_loss: 1.0794 - val_accuracy: 0.8218
# Epoch 44/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0969 - accuracy: 0.9656 - val_loss: 1.0934 - val_accuracy: 0.8215
# Epoch 45/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0957 - accuracy: 0.9662 - val_loss: 1.1179 - val_accuracy: 0.8216
# Epoch 46/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0939 - accuracy: 0.9667 - val_loss: 1.1367 - val_accuracy: 0.8229
# Epoch 47/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0920 - accuracy: 0.9675 - val_loss: 1.1788 - val_accuracy: 0.8177
# Epoch 48/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0905 - accuracy: 0.9683 - val_loss: 1.1984 - val_accuracy: 0.8192
# Epoch 49/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0892 - accuracy: 0.9686 - val_loss: 1.2008 - val_accuracy: 0.8212
# Epoch 50/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0872 - accuracy: 0.9697 - val_loss: 1.2290 - val_accuracy: 0.8200
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 1.2472 - accuracy: 0.8199
# [1.2472330331802368, 0.8198684453964233]

# %% [markdown]
# Define the `plot_learning_curves` function that plots only the losses (not the accuracy).

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.epoch,history.history['loss'], label='train loss')
    plt.plot(history.epoch,history.history['val_loss'], label='valid loss')
    plt.legend()
    plt.title('loss')
    plt.grid(True)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### [TO COMPLETE] L1 norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow to remove the overfitting effect.

# %%
#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfroms the L1-norm regularization

#[TO COMPLETE] copy the model that you previously defined that overfits the 
#training data, and add the L1-norm regularization. Use a proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1 

#In general, a layer that exploits L1-norm regularization is defined as follows:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE], kernel_regularizer=tf.keras.regularizers.l1([TO COMPLETE]))) 

model = keras.models.Sequential()
#[TO COMPLETE]
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(units=32, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(1e-3)))
model.add(keras.layers.Dense(units=16, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(1e-4)))
model.add(keras.layers.Dense(units=4, activation="softmax", kernel_regularizer=tf.keras.regularizers.l1(1e-4)))


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=50,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.7760 - accuracy: 0.8120 - val_loss: 0.6740 - val_accuracy: 0.8302
# Epoch 2/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.6369 - accuracy: 0.8368 - val_loss: 0.6189 - val_accuracy: 0.8400
# Epoch 3/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.6088 - accuracy: 0.8405 - val_loss: 0.6065 - val_accuracy: 0.8406
# Epoch 4/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5949 - accuracy: 0.8423 - val_loss: 0.6133 - val_accuracy: 0.8327
# Epoch 5/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5882 - accuracy: 0.8417 - val_loss: 0.5849 - val_accuracy: 0.8432
# Epoch 6/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5786 - accuracy: 0.8436 - val_loss: 0.5849 - val_accuracy: 0.8413
# Epoch 7/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5756 - accuracy: 0.8441 - val_loss: 0.5892 - val_accuracy: 0.8397
# Epoch 8/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5721 - accuracy: 0.8436 - val_loss: 0.5767 - val_accuracy: 0.8442
# Epoch 9/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5679 - accuracy: 0.8449 - val_loss: 0.5753 - val_accuracy: 0.8426
# Epoch 10/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5660 - accuracy: 0.8441 - val_loss: 0.5790 - val_accuracy: 0.8422
# Epoch 11/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5642 - accuracy: 0.8444 - val_loss: 0.5700 - val_accuracy: 0.8438
# Epoch 12/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5620 - accuracy: 0.8453 - val_loss: 0.5645 - val_accuracy: 0.8457
# Epoch 13/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5606 - accuracy: 0.8446 - val_loss: 0.5588 - val_accuracy: 0.8443
# Epoch 14/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5576 - accuracy: 0.8453 - val_loss: 0.5717 - val_accuracy: 0.8382
# Epoch 15/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5568 - accuracy: 0.8435 - val_loss: 0.5595 - val_accuracy: 0.8419
# Epoch 16/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5540 - accuracy: 0.8446 - val_loss: 0.5606 - val_accuracy: 0.8433
# Epoch 17/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5527 - accuracy: 0.8450 - val_loss: 0.5575 - val_accuracy: 0.8446
# Epoch 18/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5527 - accuracy: 0.8453 - val_loss: 0.5544 - val_accuracy: 0.8437
# Epoch 19/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5516 - accuracy: 0.8449 - val_loss: 0.5522 - val_accuracy: 0.8447
# Epoch 20/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5503 - accuracy: 0.8448 - val_loss: 0.5639 - val_accuracy: 0.8426
# Epoch 21/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5504 - accuracy: 0.8443 - val_loss: 0.5619 - val_accuracy: 0.8432
# Epoch 22/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5502 - accuracy: 0.8449 - val_loss: 0.5626 - val_accuracy: 0.8391
# Epoch 23/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5491 - accuracy: 0.8452 - val_loss: 0.5525 - val_accuracy: 0.8462
# Epoch 24/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5498 - accuracy: 0.8448 - val_loss: 0.5552 - val_accuracy: 0.8469
# Epoch 25/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5505 - accuracy: 0.8460 - val_loss: 0.5523 - val_accuracy: 0.8444
# Epoch 26/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5500 - accuracy: 0.8442 - val_loss: 0.5632 - val_accuracy: 0.8415
# Epoch 27/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5503 - accuracy: 0.8455 - val_loss: 0.5558 - val_accuracy: 0.8390
# Epoch 28/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5502 - accuracy: 0.8452 - val_loss: 0.5568 - val_accuracy: 0.8413
# Epoch 29/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5505 - accuracy: 0.8454 - val_loss: 0.5520 - val_accuracy: 0.8455
# Epoch 30/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5492 - accuracy: 0.8460 - val_loss: 0.5594 - val_accuracy: 0.8453
# Epoch 31/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5503 - accuracy: 0.8458 - val_loss: 0.5699 - val_accuracy: 0.8380
# Epoch 32/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5503 - accuracy: 0.8455 - val_loss: 0.5584 - val_accuracy: 0.8412
# Epoch 33/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5488 - accuracy: 0.8465 - val_loss: 0.5602 - val_accuracy: 0.8457
# Epoch 34/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5485 - accuracy: 0.8465 - val_loss: 0.5585 - val_accuracy: 0.8477
# Epoch 35/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5495 - accuracy: 0.8454 - val_loss: 0.5584 - val_accuracy: 0.8441
# Epoch 36/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5483 - accuracy: 0.8460 - val_loss: 0.5605 - val_accuracy: 0.8435
# Epoch 37/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5483 - accuracy: 0.8465 - val_loss: 0.5706 - val_accuracy: 0.8398
# Epoch 38/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5485 - accuracy: 0.8463 - val_loss: 0.5472 - val_accuracy: 0.8461
# Epoch 39/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5477 - accuracy: 0.8463 - val_loss: 0.5535 - val_accuracy: 0.8439
# Epoch 40/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5468 - accuracy: 0.8466 - val_loss: 0.5574 - val_accuracy: 0.8446
# Epoch 41/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5472 - accuracy: 0.8464 - val_loss: 0.5553 - val_accuracy: 0.8441
# Epoch 42/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5477 - accuracy: 0.8460 - val_loss: 0.5500 - val_accuracy: 0.8458
# Epoch 43/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5480 - accuracy: 0.8462 - val_loss: 0.5596 - val_accuracy: 0.8397
# Epoch 44/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5471 - accuracy: 0.8462 - val_loss: 0.5541 - val_accuracy: 0.8433
# Epoch 45/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5480 - accuracy: 0.8468 - val_loss: 0.5562 - val_accuracy: 0.8418
# Epoch 46/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5477 - accuracy: 0.8465 - val_loss: 0.5551 - val_accuracy: 0.8443
# Epoch 47/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5478 - accuracy: 0.8463 - val_loss: 0.5493 - val_accuracy: 0.8486
# Epoch 48/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5468 - accuracy: 0.8465 - val_loss: 0.5535 - val_accuracy: 0.8466
# Epoch 49/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5475 - accuracy: 0.8456 - val_loss: 0.5546 - val_accuracy: 0.8425
# Epoch 50/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.5489 - accuracy: 0.8460 - val_loss: 0.5560 - val_accuracy: 0.8408
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.5694 - accuracy: 0.8404

# %% [markdown]
# ### [TO COMPLETE] L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainig data, and add the L2-norm regularization. Use proper values for the
#alpha hyper-parameters, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1

#In general, a layer that exploits L2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE],kernel_regularizer=tf.keras.regularizers.l2([TO COMPLETE]))) 

model = keras.models.Sequential()
#[TO COMPLETE]
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(units=32, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-3)))
model.add(keras.layers.Dense(units=16, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)))
model.add(keras.layers.Dense(units=4, activation="softmax", kernel_regularizer=tf.keras.regularizers.l2(1e-4)))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=50,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5498 - accuracy: 0.8253 - val_loss: 0.5009 - val_accuracy: 0.8409
# Epoch 2/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4838 - accuracy: 0.8448 - val_loss: 0.4816 - val_accuracy: 0.8465
# Epoch 3/50
# 3375/3375 [==============================] - 11s 3ms/step - loss: 0.4693 - accuracy: 0.8500 - val_loss: 0.4746 - val_accuracy: 0.8482
# Epoch 4/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4609 - accuracy: 0.8525 - val_loss: 0.4830 - val_accuracy: 0.8447
# Epoch 5/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4553 - accuracy: 0.8558 - val_loss: 0.4691 - val_accuracy: 0.8487
# Epoch 6/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4501 - accuracy: 0.8579 - val_loss: 0.4737 - val_accuracy: 0.8497
# Epoch 7/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4468 - accuracy: 0.8600 - val_loss: 0.4819 - val_accuracy: 0.8472
# Epoch 8/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4444 - accuracy: 0.8602 - val_loss: 0.4645 - val_accuracy: 0.8545
# Epoch 9/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4408 - accuracy: 0.8615 - val_loss: 0.4726 - val_accuracy: 0.8498
# Epoch 10/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.
50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4252 - accuracy: 0.8686 - val_loss: 0.4582 - val_accuracy: 0.8591
# Epoch 42/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4251 - accuracy: 0.8694 - val_loss: 0.4600 - val_accuracy: 0.8597
# Epoch 43/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4254 - accuracy: 0.8690 - val_loss: 0.4654 - val_accuracy: 0.8543
# Epoch 44/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4247 - accuracy: 0.8701 - val_loss: 0.4611 - val_accuracy: 0.8559
# Epoch 45/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4253 - accuracy: 0.8695 - val_loss: 0.4615 - val_accuracy: 0.8568
# Epoch 46/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4250 - accuracy: 0.8694 - val_loss: 0.4638 - val_accuracy: 0.8556
# Epoch 47/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4246 - accuracy: 0.8697 - val_loss: 0.4605 - val_accuracy: 0.8560
# Epoch 48/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4240 - accuracy: 0.8698 - val_loss: 0.4613 - val_accuracy: 0.8579
# Epoch 49/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4237 - accuracy: 0.8698 - val_loss: 0.4611 - val_accuracy: 0.8582
# Epoch 50/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4250 - accuracy: 0.8696 - val_loss: 0.4612 - val_accuracy: 0.8576
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4746 - accuracy: 0.8499

# %% [markdown]
# ###[TO COMPLETE] Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (`patience` hyper-parameter), it stops the training phase.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainnig data
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(units=32, activation="relu"))
model.add(keras.layers.Dense(units=16, activation="relu"))
model.add(keras.layers.Dense(units=4, activation="softmax"))


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate

              metrics=["accuracy"])

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the early stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=5),#[TO COMPLETE] play with patience and find the value that prevents the model from overfitting.


    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train, y_train, epochs=50,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4655 - accuracy: 0.8319 - val_loss: 0.4122 - val_accuracy: 0.8529
# Epoch 2/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3886 - accuracy: 0.8581 - val_loss: 0.3984 - val_accuracy: 0.8554
# Epoch 3/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3609 - accuracy: 0.8672 - val_loss: 0.3923 - val_accuracy: 0.8579
# Epoch 4/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3376 - accuracy: 0.8760 - val_loss: 0.3899 - val_accuracy: 0.8604
# Epoch 5/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3176 - accuracy: 0.8851 - val_loss: 0.3931 - val_accuracy: 0.8556
# Epoch 6/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3002 - accuracy: 0.8903 - val_loss: 0.4023 - val_accuracy: 0.8553
# Epoch 7/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2836 - accuracy: 0.8971 - val_loss: 0.4126 - val_accuracy: 0.8546
# Epoch 8/50
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.2701 - accuracy: 0.9032 - val_loss: 0.4185 - val_accuracy: 0.8527
# Epoch 9/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2563 - accuracy: 0.9087 - val_loss: 0.4353 - val_accuracy: 0.8497
# Model Evaluation
# 238/238 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8555

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(4, activation="softmax")
                                     ])
    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train, y_train,
                        validation_data=(X_valid, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
    print("evaluation on test set")
    model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.8467 - accuracy: 0.6874 - val_loss: 0.5046 - val_accuracy: 0.8340
# Epoch 2/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4544 - accuracy: 0.8446 - val_loss: 0.4450 - val_accuracy: 0.8475
# Epoch 3/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4203 - accuracy: 0.8537 - val_loss: 0.4310 - val_accuracy: 0.8498
# Epoch 4/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4071 - accuracy: 0.8567 - val_loss: 0.4227 - val_accuracy: 0.8508
# Epoch 5/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3996 - accuracy: 0.8588 - val_loss: 0.4193 - val_accuracy: 0.8516
# Epoch 6/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3944 - accuracy: 0.8601 - val_loss: 0.4160 - val_accuracy: 0.8524
# Epoch 7/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3904 - accuracy: 0.8612 - val_loss: 0.4137 - val_accuracy: 0.8531
# Epoch 8/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3869 - accuracy: 0.8615 - val_loss: 0.4120 - val_accuracy: 0.8542
# Epoch 9/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3839 - accuracy: 0.8623 - val_loss: 0.4095 - val_accuracy: 0.8547
# Epoch 10/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3812 - accuracy: 0.8624 - val_loss: 0.4084 - val_accuracy: 0.8550
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8493
# Epoch 1/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4643 - accuracy: 0.8306 - val_loss: 0.4359 - val_accuracy: 0.8462
# Epoch 2/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.4096 - accuracy: 0.8509 - val_loss: 0.4190 - val_accuracy: 0.8502
# Epoch 3/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3899 - accuracy: 0.8597 - val_loss: 0.4103 - val_accuracy: 0.8524
# Epoch 4/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3747 - accuracy: 0.8646 - val_loss: 0.4130 - val_accuracy: 0.8538
# Epoch 5/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3630 - accuracy: 0.8688 - val_loss: 0.4293 - val_accuracy: 0.8510
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4392 - accuracy: 0.8412
# Epoch 1/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.6563 - accuracy: 0.7706 - val_loss: 0.5774 - val_accuracy: 0.7857
# Epoch 2/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.7391 - accuracy: 0.7150 - val_loss: 0.6771 - val_accuracy: 0.7847
# Epoch 3/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.7370 - accuracy: 0.7619 - val_loss: 0.7410 - val_accuracy: 0.7712
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.7269 - accuracy: 0.7684

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_acc_and_loss(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# ### [TO COMPLETE] GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`.

# %% [markdown]
# Let's Create a `build_model()` function that takes two arguments, `n_neurons` and `learning_rate`, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time requirements of the process we will consider only these two hyper-paramters.
#
# [TO COMPLETE] in the following code cell define the `build_model` function.

# %%
def build_model(n_units=30, learning_rate=1e-3):
    # The function has to build a model similar to the ones we used in previuous execises:
    #- a input layer 
    #- one or two Dense layers composed of n_units and that exploit Relu activation function 
    #- the output layer that uses the sigmoid activation function
    # Then, the model has to be compiled.
    model = keras.models.Sequential([
                                    #[TO COMPLETE]
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(n_units, activation="sigmoid")
                                     ])
    
    # [TO COMPLETE] Then, the model has to be compiled.
    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
    
    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [40, 45, 50],# [TO COMPLETE] insert a list that contains few (2 or 3) reasonable value
    "learning_rate": [1e-3, 1e-4, 1e-5] #[TO COMPLETE] insert a list that contains few (2 or 3) reasonable values
    #Check how the time required to perform GRID search increases when increasing the number of values for each hyper-parameter.
}

# %% [markdown]
# Use a `sklearn.model_selection.GridSearchCV` to search the hyperparameter space of your `KerasRegressor`

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train.numpy(), y_train.numpy(), epochs=5,#The number of epochs can be modified (check what happens by increasing it)
#epochs (10,5) = 5 ::::> 21 min
#epochs (10,5) = 8 ::::> 40 min
#epochs (10,5) = 10 ::::> 56 min
#epochs (40,45,50) = 5 ::::> 29 min
                validation_data=(X_valid.numpy(), y_valid.numpy()))
# Out:
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5271 - accuracy: 0.8190 - val_loss: 0.4375 - val_accuracy: 0.8432
# Epoch 2/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3981 - accuracy: 0.8554 - val_loss: 0.3992 - val_accuracy: 0.8553
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3653 - accuracy: 0.8661 - val_loss: 0.3984 - val_accuracy: 0.8544
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3373 - accuracy: 0.8768 - val_loss: 0.3955 - val_accuracy: 0.8564
# Epoch 5/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3106 - accuracy: 0.8875 - val_loss: 0.4104 - val_accuracy: 0.8517
# 675/675 [==============================] - 1s 1ms/step - loss: 0.3980 - accuracy: 0.8581
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5208 - accuracy: 0.8229 - val_loss: 0.4297 - val_accuracy: 0.8485
# Epoch 2/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3978 - accuracy: 0.8551 - val_loss: 0.4057 - val_accuracy: 0.8555
# Epoch 3/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3696 - accuracy: 0.8639 - val_loss: 0.4062 - val_accuracy: 0.8553
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3446 - accuracy: 0.8737 - val_loss: 0.4033 - val_accuracy: 0.8575
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3205 - accuracy: 0.8833 - val_loss: 0.4084 - val_accuracy: 0.8535
# 675/675 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.8526
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5139 - accuracy: 0.8252 - val_loss: 0.4274 - val_accuracy: 0.8490
# Epoch 2/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3956 - accuracy: 0.8569 - val_loss: 0.4067 - val_accuracy: 0.8508
# Epoch 3/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3684 - accuracy: 0.8652 - val_loss: 0.3939 - val_accuracy: 0.8562
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3437 - accuracy: 0.8747 - val_loss: 0.3982 - val_accuracy: 0.8566
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3194 - accuracy: 0.8833 - val_loss: 0.3959 - val_accuracy: 0.8576
# 675/675 [==============================] - 1s 1ms/step - loss: 0.4056 - accuracy: 0.8530
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5116 - accuracy: 0.8228 - val_loss: 0.4256 - val_accuracy: 0.8483
# Epoch 2/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3982 - accuracy: 0.8544 - val_loss: 0.4032 - val_accuracy: 0.8533
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3691 - accuracy: 0.8638 - val_loss: 0.3943 - val_accuracy: 0.8558
# Epoch 4/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3438 - accuracy: 0.8735 - val_loss: 0.3963 - val_accuracy: 0.8594
# Epoch 5/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3194 - accuracy: 0.8810 - val_loss: 0.3979 - val_accuracy: 0.8553
# 675/675 [==============================] - 1s 1ms/step - loss: 0.3892 - accuracy: 0.8624
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5165 - accuracy: 0.8217 - val_loss: 0.4277 - val_accuracy: 0.8496
# Epoch 2/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.4008 - accuracy: 0.8539 - val_loss: 0.4084 - val_accuracy: 0.8521
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3727 - accuracy: 0.8629 - val_loss: 0.3980 - val_accuracy: 0.8562
# Epoch 4/5
# 2700/2700 [==============================] - 5s 2ms/step - loss: 0.3463 - accuracy: 0.8721 - val_loss: 0.3958 - val_accuracy: 0.8558
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3202 - accuracy: 0.8821 - val_loss: 0.4032 - val_accuracy: 0.8553
# 675/675 [==============================] - 1s 1ms/step - loss: 0.4082 - accuracy: 0.8554
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5153 - accuracy: 0.8224 - val_loss: 0.4384 - val_accuracy: 0.8444
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.3988 - accuracy: 0.8559 - val_loss: 0.4001 - val_accuracy: 0.8548
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.7918 - accuracy: 0.7891 - val_loss: 0.7251 - val_accuracy: 0.7946
# 675/675 [==============================] - 1s 1ms/step - loss: 0.7234 - accuracy: 0.7943
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 3.4381 - accuracy: 0.2598 - val_loss: 2.5795 - val_accuracy: 0.3185
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.8461 - accuracy: 0.3823 - val_loss: 1.4051 - val_accuracy: 0.5862
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.2411 - accuracy: 0.7073 - val_loss: 1.1091 - val_accuracy: 0.7587
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.9992 - accuracy: 0.7742 - val_loss: 0.9025 - val_accuracy: 0.7852
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.8167 - accuracy: 0.7960 - val_loss: 0.7450 - val_accuracy: 0.8015
# 675/675 [==============================] - 1s 1ms/step - loss: 0.7473 - accuracy: 0.7961
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 3.4096 - accuracy: 0.2511 - val_loss: 2.4678 - val_accuracy: 0.3462
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.6867 - accuracy: 0.4740 - val_loss: 1.2634 - val_accuracy: 0.6797
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.0906 - accuracy: 0.7341 - val_loss: 0.9517 - val_accuracy: 0.7670
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.8506 - accuracy: 0.7819 - val_loss: 0.7671 - val_accuracy: 0.7901
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.7038 - accuracy: 0.8014 - val_loss: 0.6546 - val_accuracy: 0.8054
# 675/675 [==============================] - 1s 1ms/step - loss: 0.6476 - accuracy: 0.8099
# Epoch 1/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 3.3386 - accuracy: 0.2482 - val_loss: 2.3122 - val_accuracy: 0.3887
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.5840 - accuracy: 0.5245 - val_loss: 1.2213 - val_accuracy: 0.6906
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.0615 - accuracy: 0.7405 - val_loss: 0.9334 - val_accuracy: 0.7710
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.8315 - accuracy: 0.7873 - val_loss: 0.7530 - val_accuracy: 0.7959
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.6861 - accuracy: 0.8061 - val_loss: 0.6427 - val_accuracy: 0.8088
# 675/675 [==============================] - 1s 1ms/step - loss: 0.6417 - accuracy: 0.8117
# Epoch 1/5
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4993 - accuracy: 0.8274 - val_loss: 0.4221 - val_accuracy: 0.8491
# Epoch 2/5
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3928 - accuracy: 0.8567 - val_loss: 0.4016 - val_accuracy: 0.8531
# Epoch 3/5
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3644 - accuracy: 0.8663 - val_loss: 0.3893 - val_accuracy: 0.8592
# Epoch 4/5
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3406 - accuracy: 0.8741 - val_loss: 0.3942 - val_accuracy: 0.8550
# Epoch 5/5
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3190 - accuracy: 0.8822 - val_loss: 0.3913 - val_accuracy: 0.8576
# GridSearchCV(estimator=<keras.wrappers.scikit_learn.KerasRegressor object at 0x7f94992c0110>,
#              param_grid={'learning_rate': [0.001, 0.0001, 1e-05],
#                          'n_units': [40, 45, 50]})

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test, y_test)
# Out:
# {'learning_rate': 0.001, 'n_units': 40}
# 238/238 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8546
# [0.39923784136772156, 0.8546052575111389]
